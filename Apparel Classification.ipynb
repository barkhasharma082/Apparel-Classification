# %%
# !pip install PyDrive
# Out:
# ...
#      |████████████████████████████████| 993kB 451kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 143kB 548kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 102kB 633kB/s ta 0:00:011
# ...
#      |████████████████████████████████| 102kB 563kB/s ta 0:00:01
# ...
#      |████████████████████████████████| 81kB 466kB/s eta 0:00:011
# ...
#      |████████████████████████████████| 81kB 567kB/s eta 0:00:011
# ...
#      |████████████████████████████████| 133kB 586kB/s eta 0:00:01
# ...
#   Created wheel for PyDrive: filename=PyDrive-1.3.1-cp37-none-any.whl size=27436 sha256=6bf1877cb6416a130ae43b77f8206db2f6e01acc3028bed5595d7666ac3bfa50
#   Stored in directory: /home/student/.cache/pip/wheels/fa/d2/9a/d3b6b506c2da98289e5d417215ce34b696db856643bad779f4
# ...
#   Created wheel for google-api-python-client: filename=google_api_python_client-1.7.11-cp37-none-any.whl size=56530 sha256=4f2444bcee02cfb0a992bac09bd2696cd1ab31928a91e3524daa7bef58970367
# ...

# %%
# importing required modules 
from zipfile import ZipFile 

# specifying the zip file name 
file_name = "/home/student/Downloads/train_LbELtWX.zip"

# opening the zip file in READ mode 
with ZipFile(file_name, 'r') as zip: 
	# printing all the contents of the zip file 
	zip.printdir() 

	# extracting all the files 
	print('Extracting all the files now...') 
	zip.extractall() 
	print('Done!')
# Out:
# File Name                                             Modified             Size
# train/                                         2018-05-30 12:26:42            0
# train/3751.png                                 2018-05-30 12:25:56         1394
# train/1986.png                                 2018-05-30 12:25:54          911
# train/46774.png                                2018-05-30 12:26:30         1594
# train/1386.png                                 2018-05-30 12:25:54         1130
# train/11162.png                                2018-05-30 12:26:02          880
# train/52576.png                                2018-05-30 12:26:36         1032
# train/24590.png                                2018-05-30 12:26:12         1241
# train/780.png                                  2018-05-30 12:25:52         1723
# train/46235.png                                2018-05-30 12:26:30         1044
# train/22625.png                                2018-05-30 12:26:10         1132
# ...

# %%
# !pip install keras
# Out:
# ...
#      |████████████████████████████████| 378kB 229kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 51kB 1.5MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 51kB 378kB/s eta 0:00:01
# ...

# %%
# !pip install tensorflow
# Out:
# ...
#      |████████████████████████████████| 86.3MB 126kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 450kB 319kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.8MB 373kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 71kB 334kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 112kB 515kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.3MB 330kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 61kB 1.3MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.4MB 319kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 92kB 389kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 153kB 525kB/s eta 0:00:01
# ...
#   Created wheel for opt-einsum: filename=opt_einsum-3.1.0-cp37-none-any.whl size=61682 sha256=5ce3b7b0242b3ca44054952cd5e96edb6eeb461d22cd74ea985f07a8d8533058
#   Stored in directory: /home/student/.cache/pip/wheels/2c/b1/94/43d03e130b929aae7ba3f8d15cbd7bc0d1cb5bb38a5c721833
# ...

# %%
import os
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import to_categorical
from keras.preprocessing import image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from tqdm import tqdm
# Out:
# Using TensorFlow backend.

# %%
train = pd.read_csv('train.csv')

# %%
# We have grayscale images, so while loading the images we will keep grayscale=True, if you have RGB images, you should set grayscale as False
train_image = []
for i in tqdm(range(train.shape[0])):
    img = image.load_img('train/'+train['id'][i].astype('str')+'.png', target_size=(28,28,1), grayscale=True)
    img = image.img_to_array(img)
    img = img/255
    train_image.append(img)
X = np.array(train_image)
# Out:
#   0%|          | 0/60000 [00:00<?, ?it/s]/home/student/anaconda3/lib/python3.7/site-packages/keras_preprocessing/image/utils.py:104: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# 100%|██████████| 60000/60000 [08:57<00:00, 111.55it/s]

# %%
#As it is a multi-class classification problem (10 classes), we will one-hot encode the target variable.
y=train['label'].values
y = to_categorical(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

# %%
#Define the model structure.

#We will create a simple architecture with 2 convolutional layers, one dense hidden layer and an output layer.
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),activation='relu',input_shape=(28,28,1)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# %%
#we will compile the model we have created
model.compile(loss='categorical_crossentropy',optimizer='Adam',metrics=['accuracy'])

# %%
#training the model
model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 48000/48000 [==============================] - 104s 2ms/step - loss: 0.5006 - accuracy: 0.8230 - val_loss: 0.3277 - val_accuracy: 0.8798
# Epoch 2/10
# 48000/48000 [==============================] - 103s 2ms/step - loss: 0.3397 - accuracy: 0.8784 - val_loss: 0.2730 - val_accuracy: 0.8982
# Epoch 3/10
# 48000/48000 [==============================] - 104s 2ms/step - loss: 0.2842 - accuracy: 0.8978 - val_loss: 0.2516 - val_accuracy: 0.9057
# Epoch 4/10
# 48000/48000 [==============================] - 109s 2ms/step - loss: 0.2534 - accuracy: 0.9064 - val_loss: 0.2303 - val_accuracy: 0.9138
# Epoch 5/10
# 48000/48000 [==============================] - 119s 2ms/step - loss: 0.2290 - accuracy: 0.9160 - val_loss: 0.2349 - val_accuracy: 0.9149
# Epoch 6/10
# 48000/48000 [==============================] - 116s 2ms/step - loss: 0.2050 - accuracy: 0.9236 - val_loss: 0.2332 - val_accuracy: 0.9162
# Epoch 7/10
# ...

# %%
#making predictions with test data
# specifying the zip file name 
file_name1 = "/home/student/Downloads/test_ScVgIM0.zip"

# opening the zip file in READ mode 
with ZipFile(file_name1, 'r') as zip: 
	# printing all the contents of the zip file 
	zip.printdir() 

	# extracting all the files 
	print('Extracting all the files now...') 
	zip.extractall() 
	print('Done!')
# Out:
# File Name                                             Modified             Size
# test/                                          2018-05-30 13:05:18            0
# test/62791.png                                 2018-05-30 13:05:10          772
# test/68779.png                                 2018-05-30 13:05:16         1244
# test/66131.png                                 2018-05-30 13:05:14         1239
# test/62751.png                                 2018-05-30 13:05:10         1144
# test/65428.png                                 2018-05-30 13:05:14         1410
# test/66442.png                                 2018-05-30 13:05:14          879
# test/61995.png                                 2018-05-30 13:05:10         1230
# test/62664.png                                 2018-05-30 13:05:10         1186
# test/63642.png                                 2018-05-30 13:05:12         1260
# test/62351.png                                 2018-05-30 13:05:10         1267
# ...

# %%
test = pd.read_csv('test.csv')

# %%
#we will read and store all the images here
test_image = []
for i in tqdm(range(test.shape[0])):
    img = image.load_img('test/'+test['id'][i].astype('str')+'.png', target_size=(28,28,1), grayscale=True)
    img = image.img_to_array(img)
    img = img/255
    test_image.append(img)
test = np.array(test_image)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]/home/student/anaconda3/lib/python3.7/site-packages/keras_preprocessing/image/utils.py:104: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# 100%|██████████| 10000/10000 [00:46<00:00, 216.81it/s]

# %%
# making predictions
prediction = model.predict_classes(test)

# %%
# creating submission file
sample = pd.read_csv('/home/student/Downloads/sample_submission_I5njJSF.csv')
sample['label'] = prediction
sample.to_csv('sample_cnn.csv', header=True, index=False)
